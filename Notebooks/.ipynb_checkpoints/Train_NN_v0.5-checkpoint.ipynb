# %% [markdown]
# # Train NN v0.5: Imporved version of v0.4 (NOT FINISHED YET)
#
# - generates N training samples with varied energies $K_{\alpha_1}$, energy splitting and ratios
# - trains one the MLP regressor for each parameter
# - The trained NNs are tested on training set, dev set and test set
# - No optimization have been made.
#
# - TODO:
#     - Track convergence (loss error) of NN by using verbose output of training
#         - Check https://stackoverflow.com/questions/5136611/capture-stdout-from-a-script-in-python for redirecting stdout
#     - Implement the different NNs
#     - Check why performance deteriorates for altering the ratios
#     - Split large datasets into several zipped containers
#
# Changes:
# - New:
#     - Train separate NN for each parameter but with same training set
#     - Files now named after size of data set
# - Bug fixes
#     -
# - gen_set()
#     -
# - read_input_data()
#     -

# %%
"""
Import functions and tools needed
"""
import plotly.offline as py
import plotly.tools as tls
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import numpy as np
import pandas as pd
import matplotlib
import math
import scipy.stats as sc
from scipy.special import wofz
from astropy.modeling.functional_models import Voigt1D 
from scipy.interpolate import UnivariateSpline
from sklearn.neural_network import MLPRegressor as MLPR
import time
from sklearn.externals import joblib

matplotlib.rcParams['figure.figsize']=(7,5)
py.init_notebook_mode()

def plotly_show():
    fig = plt.gcf()
    py.iplot_mpl(fig)
    plt.grid(True)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
def calc_area(x, v):
    """
    Calculates the area beneath a spectrum
    """
    width = (x[len(x)-1]-x[0])/(len(x)-1)
    area = 0
    for i in range(len(x)):
        area += v[i] * width
    return area

# %%
def gen_set(N, x, noise, Set, verbosity): 
    """
    - Generates a set with N spectra by using the superposition of TWO Voigt profiles with randomly choosen
        parameters 
            gamma1: HWHM of Lorentzian part of Voigt profile 1 
            gamma2: HWHM of Lorentzian part of Voigt profile 2
            sigma1: Standard uncertainty of Gaussian part of Voigt profile 1
            sigma2: Standard uncertainty of Gaussian part of Voigt profile 2
            epsilon: offset to energy E
        The Energy E (K alpha1) is centered around 2014eV 
    """
    if (verbosity > 0):
        start = time.time()
    # Definition of some parameters
    gamma1, sigma1 = 0.345, 0.07
    gamma2, sigma2 = 0.36, 0.08
    labels = np.array(0)
    labels = np.delete(labels, 0)
    # Creating the empty data matrix with dimensions N x d+1
    X = np.zeros((N,len(x)+3))
    runtime = np.array(0)
    runtime = np.delete(runtime, 0)
    """
    For loop loops N times to create N spectra. The single spectrum is evaluate and fitted
    on range x to get equal x values as features (Note: When trained on grid defined by x then
    real data must also be sampled on same grid!). File format:
        File dimensions: N x (2 + d), where d is number of grid points resulting from grid x
        [E dE x1 x2 ... xd]
    """
    if (verbosity > 0):
        loop_time_start = time.time()
    for i in range(N):
        # Generate random distribution (+- 1) around central value of energie E
        E_epsilon = (np.random.random_sample()-0.5)*2
        # Generate random distribution (+- 0.1) around central value of energie dE
        dE_epsilon = (np.random.random_sample()-0.5)*(0.4)
        # Generate random distribution (+- 0.05) around central value of amplitude L1
        dL1 = (np.random.random_sample()-0.5)/15
        # Generate random distribution (+- 0.05) around central value of amplitude L2
        dL2 = (np.random.random_sample()-0.5)/15
        L1 = 0.18 + dL1
        L2 = 0.3 + dL2
        E = 2014 + E_epsilon
        dE = 0.85 + dE_epsilon
        v1 = Voigt1D(x_0=E-dE, amplitude_L=L1, fwhm_L=2*gamma1, fwhm_G=2*sigma1*np.sqrt(2*np.log(2)))
        v2 = Voigt1D(x_0=E, amplitude_L=L2, fwhm_L=2*gamma2, fwhm_G=2*sigma2*np.sqrt(2*np.log(2)))
        # Fit the superposition of the voigt profiles with splines
        sp = UnivariateSpline(x,v1(x)+v2(x),s=10e-5)
        # Calculate the ratio of the areas
        R = calc_area(x, v2(x))/calc_area(x,v1(x))
        # Save values in two columns in form of [x,v(x)]
        X[i,0] = E
        X[i,1] = dE
        X[i,2] = R
        if (noise == True):
            # Apply poisson noise to the data 
            append = sp(x)
            # Magnify amplitudes to get poisson function working
            append *= 1e4
            append = np.random.poisson(append)
            for j in range(len(x)):
                X[i,j+3] = append[j]
        else: 
            append = sp(x)
            append *= 1e4
            for j in range(len(x)):
                X[i,j+3] = append[j]
        # Runtime control
        if (verbosity > 0):
            if ( i % (N/10) == 0 ):
                loop_time_end = time.time()
                time_diff = loop_time_end-loop_time_start
                runtime = np.append(runtime, time_diff)
                print("Progress: %i/%i, time for loop: %3.2fs" % (i , N, time_diff))
                loop_time_start = time.time()
    # Create pandas dataframe
    df_spectrum = pd.DataFrame(X)
    df_spectrum.to_msgpack('./data/'+Set+'.spectrum')
    # Plot verbosity information about the loop
    if (verbosity > 0):
        end = time.time()
        print("Time for generating the "+Set+" set:", end-start)
        if (verbosity > 1):
            plt.figure()
            plt.title("Runtime for generating the data set "+Set)
            plt.plot(runtime, label="Runtime per N/10 loops")
            plt.grid(True)
            plt.legend()
            plotly_show()

# %%
def read_set(Set):
    """ 
    Read data and store it in (Nxd) Martix, where N donates 
    the observation (single spectrum) and d the dth feature 
    (datapoint given by choosing x). The data gets fitted 
    by the Splines fit. Also, noise is added when reading the
    data if flag is set.
    """
    start = time.time()
    
    X = pd.read_msgpack('./data/'+Set+'.spectrum') 
    X = X.as_matrix()
    end = time.time()
    print("Time for reading "+Set+" set: %3.2fs" % (end-start))
    return X

# %%
def scale_input(X):
    """
    Feature skaling for NN apporach. It is "highly recommended" to scale input data to either [0:1] or [-1:+1] 
    or standardize it to have mean 0 and variance 1
    Source:
    http://scikit-learn.org/stable/modules/neural_networks_supervised.html#regression
    This function standardizes X 
    """
    from sklearn.preprocessing import StandardScaler  
    scaler = StandardScaler()  
    # Don't cheat - fit only on training data
    scaler.fit(X)  
    X = scaler.transform(X)  
    #for i in range(len(X)):
    #    plt.plot(x,X[i])
    #plt.grid(True)
    #plotly_show()
    return X

# %%
def NN_train(X, model, parameter):
    """
    Trains given model on data X and labels y. Returns trainings score
    """
    start = time.time()
    y = np.ravel(X[:,parameter])
    X = X[:,3:]
    # Rescale input between 0 and 1
    X /= 1e4 # factor results of rescaling in gen_set()
    X = scale_input(X)
    model.fit(X, y)
    score = model.score(X,y)
    end = time.time()
    print("Training time: %3.2f " % (end - start))
    print("Training score: %3.2f " % (score))
    return score

# %% [markdown]
# ### Begin of testing the algorithms

# %%
"""
Defining (Hyper)Parameters
"""
exp = 4 # Exponent defining the size of the file
N = int(1*10**(exp)) # Actual value
data_size = int(N/1000) # Value for labeling the data (in "kilo samples") 
x = np.arange(2008,2018,0.01) # Grid for creating and importing data
# Following the definition of the different 
"""
model_energy = MLPR(hidden_layer_sizes=(100, ), activation="relu", solver="adam", alpha=0.0001, batch_size="auto", 
             learning_rate="constant", learning_rate_init=0.001, power_t=0.5, max_iter=20000, shuffle=True, 
             random_state=None, tol=0.0001, verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, 
             early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model_splitting = MLPR(hidden_layer_sizes=(100, ), activation="relu", solver="adam", alpha=0.0001, batch_size="auto", 
             learning_rate="constant", learning_rate_init=0.001, power_t=0.5, max_iter=20000, shuffle=True, 
             random_state=None, tol=0.0001, verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, 
             early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model_ratio = MLPR(hidden_layer_sizes=(100, ), activation="relu", solver="adam", alpha=0.0001, batch_size="auto", 
             learning_rate="constant", learning_rate_init=0.001, power_t=0.5, max_iter=20000, shuffle=True, 
             random_state=None, tol=0.0001, verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, 
             early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
"""
model_energy = MLPR(hidden_layer_sizes=(100, ), max_iter=20000, activation="relu", verbose = True, 
                    solver = 'sgd',learning_rate = 'constant',learning_rate_init = 1e-5, batch_size = 400)

# %%
gen_set(N, x, noise = False, Set = "train"+str(data_size)+"k", verbosity = 1)
gen_set(int(N/10), x, noise = False, Set = "dev"+str(int(data_size/10))+"k", verbosity = 0)
gen_set(int(N/10), x, noise = False, Set = "test"+str(int(data_size/10))+"k", verbosity = 0)
# Out:
# Progress: 0/10000, time for loop: 0.00s
# Progress: 1000/10000, time for loop: 7.05s
# Progress: 2000/10000, time for loop: 7.02s
# Progress: 3000/10000, time for loop: 7.03s
# Progress: 4000/10000, time for loop: 7.19s
# Progress: 5000/10000, time for loop: 7.10s
# Progress: 6000/10000, time for loop: 7.01s
# Progress: 7000/10000, time for loop: 7.01s
# Progress: 8000/10000, time for loop: 7.08s
# Progress: 9000/10000, time for loop: 6.91s
# Time for generating the train10k set: 71.42315340042114

# %%
X_train = read_set(Set="train"+str(data_size)+"k")
X_dev = read_set(Set="dev"+str(int(data_size/10))+"k")
X_test = read_set(Set="test"+str(int(data_size/10))+"k")
# Out:
# Time for reading train10k set: 0.25s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-2bda23da1470> in <module>()
#       1 X_train = read_set(Set="train"+str(data_size)+"k")
# ----> 2 X_dev = read_set(Set="dev"+str(int(data_size/10))+"k")
#       3 X_test = read_set(Set="test"+str(int(data_size/10))+"k")
#
# <ipython-input-80-5da15fc3499e> in read_set(Set)
#       9     start = time.time()
#      10
# ---> 11     X = pd.read_msgpack('./data/'+Set+'.spectrum')
#      12     X = X.as_matrix()
#      13     end = time.time()
#
# ~\Anaconda3\lib\site-packages\pandas\io\packers.py in read_msgpack(path_or_buf, encoding, iterator, **kwargs)
#     217         return read(path_or_buf)
#     218
# --> 219     raise ValueError('path_or_buf needs to be a string file path or file-like')
#     220
#     221
#
# ValueError: path_or_buf needs to be a string file path or file-like

# %%
for i in range(1):
    print("########### RUN", i+1, "###########")
    score_energy = NN_train(X_train, model_energy, 0)
    # Save model via
    #joblib.dump(model, './data/1_neural_network.pkl')
    # Load model via
    #model2 = joblib.load('./data/1_neural_network.pkl')
    predict_train = model_energy.predict(X_train[:,3:])
    predict_dev = model_energy.predict(X_dev[:,3:])
    """
    plt.plot(X_train[:,:3]-predict_train, label=("Train set"))
    plt.plot(X_dev[:,:3]-predict_dev, label=("dev set"))
    plt.xlabel("datapoint")
    plt.ylabel("Error in arb. units")
    plt.title("Error on true label")
    abserr_train = np.absolute(X_train[:,:3]-predict_train)
    abserr_train = np.sum(abserr_train)
    plt.legend()
    plt.grid(True)
    print("Mean error per prediction in training set in run %i: %3.2f " % (i+1, abserr_train/len(X_train)))
    """
#plotly_show()
# Out:
# ########### RUN 1 ###########
# Iteration 1, loss = 554697.54630702
# Iteration 2, loss = 16114.81109459
# Iteration 3, loss = 11891.60082791
# Iteration 4, loss = 9848.09311388
# Iteration 5, loss = 8429.84535042
# Iteration 6, loss = 7170.44440147
# Iteration 7, loss = 6094.81009475
# Iteration 8, loss = 5211.08511709
# Iteration 9, loss = 4512.49032271
# Iteration 10, loss = 3828.07517718
# Iteration 11, loss = 3312.70954817
# Iteration 12, loss = 2873.72937214
# Iteration 13, loss = 2510.93124546
# Iteration 14, loss = 2229.63911826
# Iteration 15, loss = 2009.06087250
# Iteration 16, loss = 1820.63231928
# Iteration 17, loss = 1669.56508652
# Iteration 18, loss = 1534.51997675
# Iteration 19, loss = 1434.71114496
# Iteration 20, loss = 1349.33789091
# Iteration 21, loss = 1263.26287639
# Iteration 22, loss = 1188.72579552
# Iteration 23, loss = 1124.52167807
# Iteration 24, loss = 1067.64359963
# Iteration 25, loss = 1018.92178218
# Iteration 26, loss = 967.55754023
# Iteration 27, loss = 929.26174746
# Iteration 28, loss = 880.03512534
# Iteration 29, loss = 839.14223920
# Iteration 30, loss = 805.66325576
# Iteration 31, loss = 770.39371094
# Iteration 32, loss = 733.82250696
# Iteration 33, loss = 705.24815503
# Iteration 34, loss = 673.80165384
# Iteration 35, loss = 648.25229723
# Iteration 36, loss = 620.29371165
# Iteration 37, loss = 596.18924524
# Iteration 38, loss = 574.27957386
# Iteration 39, loss = 549.28101117
# Iteration 40, loss = 529.68679725
# Iteration 41, loss = 512.02280245
# Iteration 42, loss = 492.31600551
# Iteration 43, loss = 469.67287951
# Iteration 44, loss = 450.72684619
# Iteration 45, loss = 432.68743409
# Iteration 46, loss = 415.64396450
# Iteration 47, loss = 401.25146154
# Iteration 48, loss = 385.62891664
# Iteration 49, loss = 370.43568690
# Iteration 50, loss = 357.46958135
# Iteration 51, loss = 344.16351712
# Iteration 52, loss = 331.50764354
# Iteration 53, loss = 320.02266647
# Iteration 54, loss = 308.16012924
# Iteration 55, loss = 296.19869172
# Iteration 56, loss = 285.49735559
# Iteration 57, loss = 275.41302245
# Iteration 58, loss = 267.30848304
# Iteration 226, loss = 32.62517417
# Iteration 227, loss = 32.10457058
# Iteration 228, loss = 32.03798064
# Iteration 229, loss = 32.18400802
# Iteration 230, loss = 31.86941948
# Iteration 231, loss = 31.73681577
# Iteration 232, loss = 31.52386426
# Iteration 233, loss = 31.33032607
# Iteration 234, loss = 31.37813189
# Iteration 235, loss = 31.15605640
# Iteration 236, loss = 31.22314770
# Iteration 237, loss = 30.80570843
# Iteration 238, loss = 30.71921718
# Iteration 239, loss = 30.43811793
# Iteration 240, loss = 30.44115027
# Iteration 241, loss = 30.41053352
# Iteration 242, loss = 30.23010823
# Iteration 243, loss = 30.20758661
# Iteration 244, loss = 30.04572648
# Iteration 245, loss = 29.78689934
# Iteration 246, loss = 29.73259619
# Iteration 247, loss = 29.53205484
# Iteration 248, loss = 29.51388431
# Iteration 249, loss = 29.66267791
# Iteration 250, loss = 29.55237105
# Iteration 251, loss = 29.32382517
# Iteration 252, loss = 28.99129793
# Iteration 253, loss = 28.94101767
# Iteration 254, loss = 28.85701833
# Iteration 255, loss = 28.65673513
# Iteration 256, loss = 28.69500782
# Iteration 257, loss = 28.47037508
# Iteration 258, loss = 28.60666066
# Iteration 259, loss = 28.32734905
# Iteration 260, loss = 28.19495548
# Iteration 261, loss = 28.04710377
# Iteration 262, loss = 27.97868278
# Iteration 263, loss = 28.18046386
# Iteration 264, loss = 27.83653544
# Iteration 265, loss = 27.89140776
# Iteration 266, loss = 27.80224822
# Iteration 267, loss = 27.55081334
# Iteration 268, loss = 27.45947848
# Iteration 269, loss = 27.52858214
# Iteration 270, loss = 27.38965380
# Iteration 271, loss = 27.27170786
# Iteration 272, loss = 27.11781208
# Iteration 273, loss = 26.94917894
# Iteration 274, loss = 26.90319735
# Iteration 275, loss = 26.85032321
# Iteration 276, loss = 26.78251340
# Iteration 277, loss = 26.79566793
# Iteration 278, loss = 26.59128865
# Iteration 279, loss = 26.92056208
# Iteration 280, loss = 26.42617658
# Iteration 281, loss = 26.43727642
# Iteration 282, loss = 26.56998443
# Iteration 283, loss = 26.46684684
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Training time: 75.13
# Training score: -151.82

# %%
plt.plot(X_train[:,0]-predict_train[:,0], label=("Train set"))
plt.plot(X_dev[:,0]-predict_dev[:,0], label=("dev set"))
plt.xlabel("datapoint")
plt.ylabel("Error in arb. units")
plt.title("Error on true label")
abserr_train = np.absolute(X_train[:,0]-predict_train[:,0])
abserr_train = np.sum(abserr_train)
plt.legend()
plt.grid(True)
print("Mean error per prediction in training set in run %i: %3.2f " % (i+1, abserr_train/len(X_train)))
plotly_show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-628f706df44d> in <module>()
# ----> 1 plt.plot(X_train[:,0]-predict_train[:,0], label=("Train set"))
#       2 plt.plot(X_dev[:,0]-predict_dev[:,0], label=("dev set"))
#       3 plt.xlabel("datapoint")
#       4 plt.ylabel("Error in arb. units")
#       5 plt.title("Error on true label")
#
# IndexError: too many indices for array

# %%
for i in range(5):
    plt.plot(x, X_train[i,3:])
plt.show()
